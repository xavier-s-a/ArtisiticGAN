# %%
import torchvision.transforms as tt
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import os
import random
import matplotlib.pyplot as plt
from torchvision.datasets import ImageFolder
import torch.nn as nn
from torchvision.utils import save_image
from tqdm.notebook import tqdm
import torch.nn.functional as F
import torch

     

sample_dir = '/Users/xavier/Desktop/projectgen500'
os.makedirs(sample_dir, exist_ok=True)

data_dir = '/Users/xavier/Desktop/project2'
dataset = ImageFolder(data_dir)



image_size = 64
batch_size = 9
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)


train_ds = ImageFolder(data_dir, transform=tt.Compose([
    tt.Resize(image_size),
    tt.CenterCrop(image_size),
    tt.ToTensor(),
    tt.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images, nrow=3):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()), nrow=nrow).permute(1, 2, 0))

def show_batch(dl, nmax=9):
    images, _ = next(iter(dl))
    show_images(images[:nmax], nrow=3)


show_batch(train_dl)  # 
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.backends.mps.is_available():
        return torch.device('mps')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
device = get_default_device()
print(device)
train_dl = DeviceDataLoader(train_dl, device)
# Out:
# mps

# %%
# Discriminator
discriminator = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    nn.Flatten(),
    nn.Sigmoid()
)
discriminator = to_device(discriminator, device)

# Generator
latent_size = 128
generator = nn.Sequential(
    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
)
generator = to_device(generator, device)

xb = torch.randn(batch_size, latent_size, 1, 1).to(device)  # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([9, 3, 64, 64])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 44
#      42 fake_images = generator(xb)
#      43 print(fake_images.shape)
# ---> 44 show_images(fake_images)
#
# Cell In[3], line 44, in show_images(images, nrow)
#      42 ax.set_xticks([])
#      43 ax.set_yticks([])
# ---> 44 ax.imshow(make_grid(denorm(images.detach()), nrow=nrow).permute(1, 2, 0))
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5665, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5657 self.set_aspect(aspect)
#    5658 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5659                       interpolation=interpolation, origin=origin,
#    5660                       extent=extent, filternorm=filternorm,
#    5661                       filterrad=filterrad, resample=resample,
#    5662                       interpolation_stage=interpolation_stage,
#    5663                       **kwargs)
# -> 5665 im.set_data(X)
#    5666 im.set_alpha(alpha)
#    5667 if im.get_clip_path() is None:
#    5668     # image does not already have clipping set, clip to axes patch
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:697, in _ImageBase.set_data(self, A)
#     695 if isinstance(A, PIL.Image.Image):
#     696     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
#     701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:709, in safe_masked_invalid(x, copy)
#     708 def safe_masked_invalid(x, copy=False):
# --> 709     x = np.array(x, subok=True, copy=copy)
#     710     if not x.dtype.isnative:
#     711         # If we have already made a copy, do the byteswap in place, else make a
#     712         # copy with the byte order swapped.
#     713         x = x.byteswap(inplace=copy).newbyteorder('N')  # Swap to native order.
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/_tensor.py:970, in Tensor.__array__(self, dtype)
#     968     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     969 if dtype is None:
# --> 970     return self.numpy()
#     971 else:
#     972     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert mps:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
import torchvision.transforms as tt
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import os
import random
import matplotlib.pyplot as plt
from torchvision.datasets import ImageFolder
import torch.nn as nn
from torchvision.utils import save_image
from tqdm.notebook import tqdm
import torch.nn.functional as F
import torch


# Set the device
device = torch.device('mps')

# Set the directories
sample_dir = '/Users/xavier/Desktop/projectgen500'
os.makedirs(sample_dir, exist_ok=True)
data_dir = '/Users/xavier/Desktop/project2'

# Set the image parameters
image_size = 64
batch_size = 9
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# Define the dataset and dataloader
train_ds = ImageFolder(data_dir, transform=tt.Compose([
    tt.Resize(image_size),
    tt.CenterCrop(image_size),
    tt.ToTensor(),
    tt.Normalize(*stats)
]))

train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=3, pin_memory=True)

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images):
    images = images.cpu()  # Move tensor to CPU
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()), nrow=3).permute(1, 2, 0))

def show_batch(dl):
    images, _ = next(iter(dl))
    show_images(images)

show_batch(train_dl)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

def get_default_device():
    """Return the GPU device if available, else return CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to the device"""
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

device = get_default_device()
print(device)
train_dl = DeviceDataLoader(train_dl, device)

# Discriminator
discriminator = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    nn.Flatten(),
    nn.Sigmoid()
)
discriminator = to_device(discriminator, device)

# Generator
latent_size = 128
generator = nn.Sequential(
    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
)
generator = to_device(generator, device)

xb = torch.randn(batch_size, latent_size, 1, 1).to(device)  # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# cpu
# torch.Size([9, 3, 64, 64])

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()


def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    
    # Create a new folder for the current epoch
    epoch_folder = os.path.join(sample_dir, f'epoch_{index:0=4d}')
    os.makedirs(epoch_folder, exist_ok=True)
    
    for i, fake_image in enumerate(fake_images):
        fake_fname = f'generated-image-{i:0=4d}.png'
        save_image(denorm(fake_image), os.path.join(epoch_folder, fake_fname))
        print('Saving', fake_fname)
        
        if show:
            fig, ax = plt.subplots(figsize=(8, 8))
            ax.set_xticks([]); ax.set_yticks([])
            ax.imshow(fake_image.cpu().detach().permute(1, 2, 0))
            plt.show()



fixed_latent = torch.randn(9, latent_size, 1, 1, device=device)
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0000.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0001.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0002.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0003.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0004.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0005.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0006.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0007.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-image-0008.png

# %%
#import torch.cuda.memory_pool as mps_pool

def fit(epochs, lr, start_idx=1):
    #torch.mps.empty_cache()    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
        #if epoch == 300:
            # Save generated images
            #save_samples1(epoch+start_idx, fixed_latent, show=False)
        
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

fixed_latent = torch.randn(9, latent_size, 1, 1, device=device)
fit(125, lr=0.0002, start_idx=1)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [1/125], loss_g: 9.9299, loss_d: 1.4113, real_score: 0.8291, fake_score: 0.6746
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [2/125], loss_g: 12.8181, loss_d: 0.1529, real_score: 0.8843, fake_score: 0.0002
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [3/125], loss_g: 12.4400, loss_d: 0.1483, real_score: 0.8961, fake_score: 0.0001
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [4/125], loss_g: 11.4125, loss_d: 0.0472, real_score: 0.9549, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [5/125], loss_g: 11.5319, loss_d: 0.7270, real_score: 0.9939, fake_score: 0.5058
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [6/125], loss_g: 6.2570, loss_d: 0.1118, real_score: 0.9374, fake_score: 0.0392
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [7/125], loss_g: 9.7936, loss_d: 0.1964, real_score: 0.8284, fake_score: 0.0010
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [8/125], loss_g: 2.4591, loss_d: 0.3658, real_score: 0.8338, fake_score: 0.1229
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [9/125], loss_g: 5.6867, loss_d: 0.5692, real_score: 0.8611, fake_score: 0.1663
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [10/125], loss_g: 5.1402, loss_d: 0.1774, real_score: 0.8824, fake_score: 0.0337
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [11/125], loss_g: 1.4691, loss_d: 1.5485, real_score: 0.3909, fake_score: 0.0144
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [12/125], loss_g: 3.3910, loss_d: 0.1191, real_score: 0.9567, fake_score: 0.0691
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [13/125], loss_g: 5.3542, loss_d: 0.0873, real_score: 0.9377, fake_score: 0.0216
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [14/125], loss_g: 8.8192, loss_d: 0.5512, real_score: 0.8701, fake_score: 0.2914
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [48/125], loss_g: 4.7083, loss_d: 0.1948, real_score: 0.8990, fake_score: 0.0642
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [49/125], loss_g: 6.7798, loss_d: 0.4437, real_score: 0.8688, fake_score: 0.2230
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [50/125], loss_g: 4.6171, loss_d: 0.1945, real_score: 0.9899, fake_score: 0.1482
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [51/125], loss_g: 4.4819, loss_d: 0.1763, real_score: 0.9546, fake_score: 0.1170
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [52/125], loss_g: 7.0684, loss_d: 0.4986, real_score: 0.9960, fake_score: 0.3291
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [53/125], loss_g: 5.5646, loss_d: 0.2566, real_score: 0.8153, fake_score: 0.0467
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [54/125], loss_g: 7.8968, loss_d: 0.2138, real_score: 0.8558, fake_score: 0.0046
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [55/125], loss_g: 8.7677, loss_d: 0.2636, real_score: 0.7784, fake_score: 0.0013
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [56/125], loss_g: 6.4909, loss_d: 0.3647, real_score: 0.9741, fake_score: 0.2734
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [57/125], loss_g: 11.4391, loss_d: 1.2112, real_score: 0.9636, fake_score: 0.5221
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [58/125], loss_g: 4.6430, loss_d: 0.1551, real_score: 0.8807, fake_score: 0.0175
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [59/125], loss_g: 4.8871, loss_d: 0.1088, real_score: 0.9264, fake_score: 0.0206
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [60/125], loss_g: 6.6616, loss_d: 0.2556, real_score: 0.8259, fake_score: 0.0429
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [61/125], loss_g: 6.9692, loss_d: 0.2084, real_score: 0.9751, fake_score: 0.1494
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [62/125], loss_g: 8.6186, loss_d: 0.2572, real_score: 0.8135, fake_score: 0.0002
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [63/125], loss_g: 5.0606, loss_d: 0.2168, real_score: 0.9889, fake_score: 0.1656
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [64/125], loss_g: 4.8264, loss_d: 0.1737, real_score: 0.9620, fake_score: 0.1122
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [65/125], loss_g: 7.7909, loss_d: 0.0385, real_score: 0.9672, fake_score: 0.0048
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [66/125], loss_g: 6.4335, loss_d: 0.3425, real_score: 0.7554, fake_score: 0.0273
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [67/125], loss_g: 7.6710, loss_d: 0.1760, real_score: 0.9708, fake_score: 0.1137
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [68/125], loss_g: 4.9052, loss_d: 0.0865, real_score: 0.9370, fake_score: 0.0181
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [69/125], loss_g: 6.9454, loss_d: 0.0879, real_score: 0.9783, fake_score: 0.0605
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [70/125], loss_g: 5.1445, loss_d: 0.0342, real_score: 0.9905, fake_score: 0.0238
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [71/125], loss_g: 7.4470, loss_d: 0.2348, real_score: 0.9919, fake_score: 0.1761
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [72/125], loss_g: 7.1076, loss_d: 0.0709, real_score: 0.9828, fake_score: 0.0502
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [73/125], loss_g: 7.4847, loss_d: 0.1678, real_score: 0.9854, fake_score: 0.1303
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [74/125], loss_g: 7.4226, loss_d: 0.0640, real_score: 0.9422, fake_score: 0.0025
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [75/125], loss_g: 7.1141, loss_d: 0.0694, real_score: 0.9498, fake_score: 0.0148
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [76/125], loss_g: 6.7054, loss_d: 0.1217, real_score: 0.9578, fake_score: 0.0686
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [77/125], loss_g: 5.2914, loss_d: 0.0464, real_score: 0.9602, fake_score: 0.0038
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [78/125], loss_g: 4.7243, loss_d: 0.0831, real_score: 0.9575, fake_score: 0.0345
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [79/125], loss_g: 3.9203, loss_d: 0.0816, real_score: 0.9592, fake_score: 0.0375
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [80/125], loss_g: 5.1461, loss_d: 0.1137, real_score: 0.9314, fake_score: 0.0286
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [81/125], loss_g: 6.5131, loss_d: 0.1119, real_score: 0.9128, fake_score: 0.0165
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [82/125], loss_g: 5.7781, loss_d: 0.3660, real_score: 0.8738, fake_score: 0.1412
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [83/125], loss_g: 5.2573, loss_d: 0.0458, real_score: 0.9878, fake_score: 0.0325
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [84/125], loss_g: 10.1514, loss_d: 0.3215, real_score: 0.7754, fake_score: 0.0007
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [85/125], loss_g: 7.7002, loss_d: 0.0122, real_score: 0.9919, fake_score: 0.0041
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [86/125], loss_g: 5.4998, loss_d: 0.0701, real_score: 0.9790, fake_score: 0.0466
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [87/125], loss_g: 6.0470, loss_d: 0.2622, real_score: 0.9082, fake_score: 0.1194
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [88/125], loss_g: 6.7017, loss_d: 0.1321, real_score: 0.8910, fake_score: 0.0069
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [89/125], loss_g: 9.3569, loss_d: 0.1371, real_score: 0.8970, fake_score: 0.0002
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [90/125], loss_g: 14.0331, loss_d: 0.2854, real_score: 0.7725, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [91/125], loss_g: 6.6216, loss_d: 0.0268, real_score: 0.9819, fake_score: 0.0080
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [92/125], loss_g: 5.2199, loss_d: 0.0719, real_score: 0.9522, fake_score: 0.0167
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [93/125], loss_g: 7.6512, loss_d: 0.0453, real_score: 0.9602, fake_score: 0.0028
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [94/125], loss_g: 4.7157, loss_d: 0.5649, real_score: 0.7022, fake_score: 0.0029
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [95/125], loss_g: 4.8522, loss_d: 0.2232, real_score: 0.8730, fake_score: 0.0657
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [96/125], loss_g: 12.2966, loss_d: 0.6560, real_score: 0.9552, fake_score: 0.2944
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [97/125], loss_g: 4.4202, loss_d: 0.1389, real_score: 0.9126, fake_score: 0.0371
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [98/125], loss_g: 4.9812, loss_d: 0.1176, real_score: 0.9634, fake_score: 0.0746
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [99/125], loss_g: 10.2621, loss_d: 0.0245, real_score: 0.9795, fake_score: 0.0037
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [100/125], loss_g: 5.6864, loss_d: 0.0669, real_score: 0.9890, fake_score: 0.0527
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [101/125], loss_g: 9.5668, loss_d: 0.0185, real_score: 0.9854, fake_score: 0.0038
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [102/125], loss_g: 6.5839, loss_d: 0.0737, real_score: 0.9395, fake_score: 0.0069
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [103/125], loss_g: 5.5416, loss_d: 0.1647, real_score: 0.9042, fake_score: 0.0510
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [104/125], loss_g: 7.3895, loss_d: 0.0264, real_score: 0.9960, fake_score: 0.0218
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [105/125], loss_g: 5.5590, loss_d: 0.2192, real_score: 0.8348, fake_score: 0.0073
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [106/125], loss_g: 8.7747, loss_d: 0.0387, real_score: 0.9634, fake_score: 0.0008
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [107/125], loss_g: 14.3412, loss_d: 0.0261, real_score: 0.9750, fake_score: 0.0005
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [108/125], loss_g: 6.2771, loss_d: 0.0371, real_score: 0.9994, fake_score: 0.0355
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [109/125], loss_g: 4.7250, loss_d: 0.1576, real_score: 0.8884, fake_score: 0.0125
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [110/125], loss_g: 7.4977, loss_d: 0.0178, real_score: 0.9886, fake_score: 0.0063
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [111/125], loss_g: 6.1239, loss_d: 0.0490, real_score: 0.9797, fake_score: 0.0274
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [112/125], loss_g: 6.0340, loss_d: 0.0066, real_score: 0.9985, fake_score: 0.0051
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [113/125], loss_g: 6.9932, loss_d: 0.0189, real_score: 0.9963, fake_score: 0.0150
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [114/125], loss_g: 7.0123, loss_d: 0.0188, real_score: 0.9960, fake_score: 0.0147
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [115/125], loss_g: 11.0916, loss_d: 0.0565, real_score: 0.9946, fake_score: 0.0476
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [116/125], loss_g: 41.5284, loss_d: 0.0001, real_score: 0.9999, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [117/125], loss_g: 40.9164, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [118/125], loss_g: 41.9223, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [119/125], loss_g: 41.1782, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [120/125], loss_g: 40.5356, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [121/125], loss_g: 41.5747, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [122/125], loss_g: 41.3500, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [123/125], loss_g: 40.5694, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [124/125], loss_g: 41.1360, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch [125/125], loss_g: 40.9367, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-image-0000.png
# Saving generated-image-0001.png
# Saving generated-image-0002.png
# Saving generated-image-0003.png
# Saving generated-image-0004.png
# Saving generated-image-0005.png
# Saving generated-image-0006.png
# Saving generated-image-0007.png
# Saving generated-image-0008.png
# ([9.929900169372559,
#   12.818062782287598,
#   12.440028190612793,
#   11.412520408630371,
#   11.531928062438965,
#   6.256987571716309,
#   9.7936429977417,
#   2.4590868949890137,
#   5.68665885925293,
#   5.140164375305176,
#   1.469081997871399,
#   3.39101505279541,
#   5.3542351722717285,
#   8.819170951843262,
#   4.427030086517334,
#   2.406186103820801,
#   4.8590989112854,
#   4.139416217803955,
#   6.082637310028076,
#   4.192059516906738,
#   1.2353806495666504,
#   3.1276373863220215,
#   2.6359262466430664,
#   4.043879508972168,
#   4.736717700958252,
#   4.8469743728637695,
#   4.573111534118652,
#   6.499076843261719,
#   3.9334030151367188,
#   3.440977096557617,
#   3.834089517593384,
#   4.248194694519043,
#   3.1034975051879883,
#   4.013492107391357,
#   4.596307754516602,
#   5.888063430786133,
#   5.3995041847229,
#   6.054567813873291,
#   4.766382694244385,
#   3.1090874671936035,
#   4.651158332824707,
#   2.6395251750946045,
#   3.2160511016845703,
#   7.944087505340576,
#   4.544577121734619,
#   6.532310962677002,
#   2.79433274269104,
#   4.708281993865967,
#   6.779759883880615,
#   4.61711311340332,
#   4.481929302215576,
#   7.0683770179748535,
#   5.564568042755127,
#   7.896767616271973,
#   8.767657279968262,
#   6.490879058837891,
#   11.439078330993652,
#   4.643035888671875,
#   4.887105941772461,
#   6.661576271057129,
#   6.969168663024902,
#   8.618633270263672,
#   5.06062126159668,
#   4.8264479637146,
#   7.790882587432861,
#   6.433469772338867,
#   7.670966148376465,
#   4.905206680297852,
#   6.945440769195557,
#   5.144510269165039,
#   7.4470038414001465,
#   7.107632160186768,
#   7.484658241271973,
#   7.422597885131836,
#   7.1141180992126465,
#   6.705392837524414,
#   5.291363716125488,
#   4.724269390106201,
#   3.9203147888183594,
#   5.146143436431885,
#   6.513055801391602,
#   5.778127193450928,
#   5.257257461547852,
#   10.151439666748047,
#   7.700184345245361,
#   5.499812602996826,
#   6.046956539154053,
#   6.701700210571289,
#   9.356880187988281,
#   14.033100128173828,
#   6.621553421020508,
#   5.219945907592773,
#   7.651183128356934,
#   4.715734958648682,
#   4.852190017700195,
#   12.2965726852417,
#   4.42017936706543,
#   4.981194972991943,
#   10.262092590332031,
#   5.686422348022461,
kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),

    nn.Conv2d(256, 1, kernel_size=4, stride=1, padding=0, bias=False),
    nn.AdaptiveAvgPool2d(1),
    nn.Sigmoid()
)

# %%
generator = nn.Sequential(
    nn.ConvTranspose2d(latent_size, 256, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),

    nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(32),
    nn.ReLU(True),

    nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
)

# %%
from torchsummary import summary

# Display generator architecture
summary(generator, input_size=(latent_size, 1, 1))

# Display discriminator architecture
summary(discriminator, input_size=(3, image_size, image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 256, 4, 4]         524,288
#        BatchNorm2d-2            [-1, 256, 4, 4]             512
#               ReLU-3            [-1, 256, 4, 4]               0
#    ConvTranspose2d-4            [-1, 128, 8, 8]         524,288
#        BatchNorm2d-5            [-1, 128, 8, 8]             256
#               ReLU-6            [-1, 128, 8, 8]               0
#    ConvTranspose2d-7           [-1, 64, 16, 16]         131,072
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#               ReLU-9           [-1, 64, 16, 16]               0
#   ConvTranspose2d-10           [-1, 32, 32, 32]          32,768
#       BatchNorm2d-11           [-1, 32, 32, 32]              64
#              ReLU-12           [-1, 32, 32, 32]               0
#   ConvTranspose2d-13            [-1, 3, 64, 64]           1,536
#              Tanh-14            [-1, 3, 64, 64]               0
# ================================================================
# Total params: 1,214,912
# Trainable params: 1,214,912
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.59
# Params size (MB): 4.63
# Estimated Total Size (MB): 6.23
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]           1,536
#          LeakyReLU-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 16, 16]          32,768
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#          LeakyReLU-5           [-1, 64, 16, 16]               0
#             Conv2d-6            [-1, 128, 8, 8]         131,072
#        BatchNorm2d-7            [-1, 128, 8, 8]             256
#          LeakyReLU-8            [-1, 128, 8, 8]               0
#             Conv2d-9            [-1, 256, 4, 4]         524,288
#       BatchNorm2d-10            [-1, 256, 4, 4]             512
#         LeakyReLU-11            [-1, 256, 4, 4]               0
#            Conv2d-12              [-1, 1, 1, 1]           4,096
# AdaptiveAvgPool2d-13              [-1, 1, 1, 1]               0
#           Sigmoid-14              [-1, 1, 1, 1]               0
# ================================================================
# Total params: 694,656
# Trainable params: 694,656
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 1.16
# Params size (MB): 2.65
# Estimated Total Size (MB): 3.85
# ----------------------------------------------------------------
